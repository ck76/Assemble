# %% [markdown]
# - 张晓波 15027900535

# %% [markdown]
# - 环境：Ananconda
#     - 是一个基于数据分析和机器学习的集成环境。在该集成环境下就可以直接进行数据分析和机器学习的代码开发。
# - jupyter可视化的编码工具
#     - 就是一个基于浏览器的超级终端（编写代码的一个工具），可以编写程序，执行程序。
#     - jupyter就是Anaconda提供的一个编码工具。
# - jupyter工具的使用：
#     - 环境的启动：终端（cmd）录入指令【jupyter notebook】，按下回车，即可启动Ananconda服务。如果启动成功，则会自动打开你的默认浏览器。
#     - new:python3,新建一个基于Anaconda的源文件（.ipynb）,在该源文件下，我们就可以进行相关代码的编写和运行。
#     - cell分为两种模式：
#         - code：可以编写python程序代码，且点击run可以执行程序
#         - markdown：可以基于markdown的相关指定指定笔记的样式
#             - 注意：兼容html指定笔记的样式
#     - 操作快捷键
#         - 新建cell：a，b
#         - 删除cell：dd，x
#         - 运行cell：shift+enter
#         - 重新编辑cell：选中cell双击
#         - 切换cell的模式：
#             - code-》md：m
#             - md-》code：y
#         - tab：智能提示/补全
#         - 打开帮助文档：shift+tab

# %% [markdown]
# - 注意：jupyter notebook指定对应的终端目录，就是启动Ananconda后对应的根目录。

# %% [markdown]
# ### 什么是数据分析
# - 是把隐藏在一些看似杂乱无章的数据背后的信息提炼出来，总结出所研究对象的内在规律
#     - 使得数据的价值最大化
#         - 分析用户的消费行为
#             - 制定促销活动的方案
#             - 制定促销时间和粒度
#             - 计算用户的活跃度
#             - 分析产品的回购力度
#         - 分析广告点击率
#             - 决定投放时间
#             - 制定广告定向人群方案
#             - 决定相关平台的投放
#         - ......
# - 数据分析是用适当的方法对收集来的大量数据进行分析，帮助人们做出判断，以便采取适当的行动
#     - 保险公司从大量赔付申请数据中判断哪些为骗保的可能
#     - 支付宝通过从大量的用户消费记录和行为自动调整花呗的额度
#     - 短视频平台通过用户的点击和观看行为数据针对性的给用户推送喜欢的视频

# %% [markdown]
# ### 为什么学习数据分析
# - 有岗位的需求
#     - 数据竞赛平台
# - 是Python数据科学的基础
# - 是机器学习课程的基础

# %% [markdown]
# ### 数据分析实现流程
# - 提出问题
# - 准备数据
# - 分析数据
# - 获得结论
# - 成果可视化

# %% [markdown]
# # 数据分析三剑客
# - numpy
# - pandas(重点)
# - matplotlib

# %% [markdown]
# ### numpy模块
# - NumPy(Numerical Python) 是 Python 语言中做科学计算的基础库。重在于数值计算，也是大部分Python科学计算库的基础，多用于在大型、多维数组上执行的数值运算。

# %% [markdown]
# #### numpy的创建
# - 使用np.array()创建
# - 使用plt创建
# - 使用np的routines函数创建

# %%
import numpy as np

# %% [markdown]
# - 使用array()创建一个一维数组

# %%
arr = np.array([1,2,3,4,5,6])
arr
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# - 使用array()创建一个多维数组

# %%
np.array([[1,2,3],[4,5,6]])
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# - 数组和列表的区别是什么？

# %%
np.array([1,2,3.3])
# Out:
# array([1. , 2. , 3.3])

# %%
[1,2.2,'Three']
# Out:
# [1, 2.2, 'Three']

# %% [markdown]
# - 结论：
#     - numpy数组中只能存放相同类型的数组元素
#     - 数据类型优先级：str>float>int

# %% [markdown]
# - 将外部的一张图片读取加载到numpy数组中，然后尝试改变数组元素的数值查看对原始图片的影响

# %%
import matplotlib.pyplot as plt

# %%
img_arr = plt.imread('./bobo.jpg')
img_arr
# Out:
# array([[[208, 208, 208],
#         [209, 209, 209],
#         [208, 208, 208],
#         ...,
#         [234, 234, 234],
#         [234, 234, 234],
#         [234, 234, 234]],
#
#        [[209, 209, 209],
#         [209, 209, 209],
#         [208, 208, 208],
#         ...,
#         [234, 234, 234],
#         [234, 234, 234],
#         [234, 234, 234]],
#
#        [[209, 209, 209],
#         [209, 209, 209],
#         [209, 209, 209],
#         ...,
#         [234, 234, 234],
#         [234, 234, 234],
#         [234, 234, 234]],
#
#        ...,
#
#        [[157, 156, 151],
#         [110, 107, 102],
#         [101,  93,  91],
#         ...,
#         [172, 177, 183],
#         [175, 178, 183],
#         [178, 183, 187]],
#
#        [[184, 176, 165],
#         [145, 138, 120],
#         [102,  96,  82],
#         ...,
#         [163, 172, 181],
#         [173, 182, 191],
#         [179, 189, 201]],
#
#        [[192, 184, 173],
#         [162, 155, 136],
#         [116, 110,  94],
# ...

# %%
plt.imshow(img_arr)

# %%
plt.imshow(img_arr - 100)

# %% [markdown]
# - linespace()
# - arange()
# - random系列

# %%
np.linspace(0,20,num=10) #返回一个一维形式的等差数列
# Out:
# array([ 0.        ,  2.22222222,  4.44444444,  6.66666667,  8.88888889,
#        11.11111111, 13.33333333, 15.55555556, 17.77777778, 20.        ])

# %%
np.arange(0,10,step=2) #返回也是一个等差数列
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.random.randint(0,100,size=(3,4)) #返回一个三行四列二维数组，数组元素是从0-100随机选取
# Out:
# array([[91, 22, 12, 80],
#        [89, 21,  2, 56],
#        [86, 70, 92, 49]])

# %% [markdown]
# #### numpy的常用属性
# - shape
# - ndim
# - size
# - dtype

# %%
img_arr.shape #返回数组的形状
# Out:
# (626, 413, 3)

# %%
img_arr.ndim #返回数组的维度
# Out:
# 3

# %%
img_arr.size #返回的数组的元素个数
# Out:
# 775614

# %%
img_arr.dtype #返回数组元素的数据类型
# Out:
# dtype('uint8')

# %% [markdown]
# #### numpy的数据类型
# - array(dtype=?):可以设定数据类型
# - arr.dtype = '?':可以修改数据类型

# %%
arr = np.random.randint(0,100,size=(5,6))
arr
# Out:
# array([[26, 41, 85, 55, 35, 23],
#        [ 8, 72, 78, 51, 31,  5],
#        [65, 37, 50, 78, 36, 94],
#        [85,  3, 76, 17, 70, 23],
#        [47, 79, 66, 28, 32, 77]])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
#修改数组元素类型
arr.dtype = 'int8'

# %%
arr.dtype
# Out:
# dtype('int8')

# %% [markdown]
# #### numpy的索引和切片操作（重点）

# %% [markdown]
# - 索引操作和列表同理

# %%
arr = np.random.randint(0,100,size=(5,6))
arr
# Out:
# array([[ 3, 43, 85, 22, 72,  4],
#        [71, 79, 10, 37,  5, 50],
#        [99,  3,  8, 35, 65, 16],
#        [71, 45, 71, 22, 40, 90],
#        [62,  9, 43, 71, 40, 79]])

# %%
arr[2] #索引取单行
# Out:
# array([99,  3,  8, 35, 65, 16])

# %%
arr[[1,2]] #索引取多行
# Out:
# array([[71, 79, 10, 37,  5, 50],
#        [99,  3,  8, 35, 65, 16]])

# %%
arr[2,3] #索引取单值
# Out:
# 35

# %%
arr[[1,2],3] #索引取多值
# Out:
# array([37, 35])

# %% [markdown]
# - 切片操作

# %%
arr[0:2] #切出前两行
# Out:
# array([[ 3, 43, 85, 22, 72,  4],
#        [71, 79, 10, 37,  5, 50]])

# %%
arr[:,0:2] #切出前两列，逗号左边表示行，右边表示列
# Out:
# array([[ 3, 43],
#        [71, 79],
#        [99,  3],
#        [71, 45],
#        [62,  9]])

# %%
arr
# Out:
# array([[ 3, 43, 85, 22, 72,  4],
#        [71, 79, 10, 37,  5, 50],
#        [99,  3,  8, 35, 65, 16],
#        [71, 45, 71, 22, 40, 90],
#        [62,  9, 43, 71, 40, 79]])

# %%
arr[::-1] #将行倒置
# Out:
# array([[62,  9, 43, 71, 40, 79],
#        [71, 45, 71, 22, 40, 90],
#        [99,  3,  8, 35, 65, 16],
#        [71, 79, 10, 37,  5, 50],
#        [ 3, 43, 85, 22, 72,  4]])

# %%
arr[:,::-1] #列倒置
# Out:
# array([[ 4, 72, 22, 85, 43,  3],
#        [50,  5, 37, 10, 79, 71],
#        [16, 65, 35,  8,  3, 99],
#        [90, 40, 22, 71, 45, 71],
#        [79, 40, 71, 43,  9, 62]])

# %%
arr[::-1,::-1] #元素倒置
# Out:
# array([[79, 40, 71, 43,  9, 62],
#        [90, 40, 22, 71, 45, 71],
#        [16, 65, 35,  8,  3, 99],
#        [50,  5, 37, 10, 79, 71],
#        [ 4, 72, 22, 85, 43,  3]])

# %%
#将图片进行翻转
plt.imshow(img_arr[::-1,::-1,::-1])

# %% [markdown]
# - 对图像进行裁剪
#     - 将脸部图像裁剪下来

# %%
plt.imshow(img_arr)

# %%
plt.imshow(img_arr[80:400,75:320,:])

# %% [markdown]
# #### 变形reshape:可以将x维度的数组变换成y维度的数组
# - 注意：变形前和变形后数组的容量不可以发生变化

# %%
arr.reshape((2,15))
# Out:
# array([[ 3, 43, 85, 22, 72,  4, 71, 79, 10, 37,  5, 50, 99,  3,  8],
#        [35, 65, 16, 71, 45, 71, 22, 40, 90, 62,  9, 43, 71, 40, 79]])

# %%
arr.reshape((30,))
# Out:
# array([ 3, 43, 85, 22, 72,  4, 71, 79, 10, 37,  5, 50, 99,  3,  8, 35, 65,
#        16, 71, 45, 71, 22, 40, 90, 62,  9, 43, 71, 40, 79])

# %% [markdown]
# #### 级联操作
#     - 将多个numpy数组进行横向或者纵向的拼接
# - axis轴向的理解
#     - 0:列
#     - 1:行
# - 问题：
#     - 级联的两个数组维度一样，但是行列个数不一样会如何？
#         - 维度不一致，一定不可以级联，但是维度一致，行列不一致也可以适当级联。

# %%
np.concatenate((arr,arr,arr),axis=1)
# Out:
# array([[ 3, 43, 85, 22, 72,  4,  3, 43, 85, 22, 72,  4,  3, 43, 85, 22,
#         72,  4],
#        [71, 79, 10, 37,  5, 50, 71, 79, 10, 37,  5, 50, 71, 79, 10, 37,
#          5, 50],
#        [99,  3,  8, 35, 65, 16, 99,  3,  8, 35, 65, 16, 99,  3,  8, 35,
#         65, 16],
#        [71, 45, 71, 22, 40, 90, 71, 45, 71, 22, 40, 90, 71, 45, 71, 22,
#         40, 90],
#        [62,  9, 43, 71, 40, 79, 62,  9, 43, 71, 40, 79, 62,  9, 43, 71,
#         40, 79]])

# %%
arr1 = np.random.randint(0,100,size=(5,5))
arr1
# Out:
# array([[23, 71, 82, 73, 51],
#        [62, 66, 85, 10, 68],
#        [24, 29, 62, 94,  8],
#        [29, 25, 11, 48, 50],
#        [39, 82, 99, 58, 13]])

# %%
np.concatenate((arr,arr1),axis=1) #不匹配级联
# Out:
# array([[ 3, 43, 85, 22, 72,  4, 23, 71, 82, 73, 51],
#        [71, 79, 10, 37,  5, 50, 62, 66, 85, 10, 68],
#        [99,  3,  8, 35, 65, 16, 24, 29, 62, 94,  8],
#        [71, 45, 71, 22, 40, 90, 29, 25, 11, 48, 50],
#        [62,  9, 43, 71, 40, 79, 39, 82, 99, 58, 13]])

# %%
arr_3 = np.concatenate((img_arr,img_arr,img_arr),axis=1)
arr_9 = np.concatenate((arr_3,arr_3,arr_3),axis=0)
plt.imshow(arr_9)

# %% [markdown]
# #### 常用的聚合操作
# - sum,max,min,mean

# %%
arr.sum(axis=0)
# Out:
# array([306, 179, 217, 187, 222, 239])

# %%
arr.mean(axis=0)
# Out:
# array([61.2, 35.8, 43.4, 37.4, 44.4, 47.8])

# %% [markdown]
# #### 常用的数学函数
# - NumPy 提供了标准的三角函数：sin()、cos()、tan()
# - numpy.around(a,decimals) 函数返回指定数字的四舍五入值。
#     - 参数说明：
#         - a: 数组
#         - decimals: 舍入的小数位数。 默认值为0。 如果为负，整数将四舍五入到小数点左侧的位置

# %%
np.sin(3.123)
# Out:
# 0.018591582402588132

# %% [markdown]
# #### 常用的统计函数
# - numpy.amin() 和 numpy.amax()，用于计算数组中的元素沿指定轴的最小、最大值。
# - numpy.ptp():计算数组中元素最大值与最小值的差（最大值 - 最小值）。
# - numpy.median() 函数用于计算数组 a 中元素的中位数（中值）
# - 标准差std():标准差是一组数据平均值分散程度的一种度量。
#     - 公式：std = sqrt(mean((x - x.mean())**2))
#     - 如果数组是 [1，2，3，4]，则其平均值为 2.5。 因此，差的平方是 [2.25,0.25,0.25,2.25]，并且其平均值的平方根除以 4，即 sqrt(5/4) ，结果为 1.1180339887498949。
# - 方差var()：统计中的方差（样本方差）是每个样本值与全体样本值的平均数之差的平方值的平均数，即 mean((x - x.mean())** 2)。换句话说，标准差是方差的平方根。

# %%
np.median(arr[0]) #返回一组数据的中位数
# Out:
# 32.5

# %%
np.std(arr[0])
# Out:
# 31.693409760109787

# %%
np.var(arr[0])
# Out:
# 1004.4722222222223

# %% [markdown]
# ### 矩阵相关
# - NumPy 中包含了一个矩阵库 numpy.matlib，该模块中的函数返回的是一个矩阵，而不是 ndarray 对象。一个 的矩阵是一个由行（row）列（column）元素排列成的矩形阵列。

# %% [markdown]
# - numpy.matlib.identity() 函数返回给定大小的单位矩阵。单位矩阵是个方阵，从左上角到右下角的对角线（称为主对角线）上的元素均为 1，除此以外全都为 0。

# %%
arr
# Out:
# array([[ 3, 43, 85, 22, 72,  4],
#        [71, 79, 10, 37,  5, 50],
#        [99,  3,  8, 35, 65, 16],
#        [71, 45, 71, 22, 40, 90],
#        [62,  9, 43, 71, 40, 79]])

# %% [markdown]
# - 转置矩阵
#     - .T:将原始数组的行变列，列变行

# %%
arr.T
# Out:
# array([[ 3, 71, 99, 71, 62],
#        [43, 79,  3, 45,  9],
#        [85, 10,  8, 71, 43],
#        [22, 37, 35, 22, 71],
#        [72,  5, 65, 40, 40],
#        [ 4, 50, 16, 90, 79]])

# %% [markdown]
# - 矩阵相乘
#     - numpy.dot(a, b, out=None)
#         - a : ndarray 数组
#         - b : ndarray 数组
#     - 第一个矩阵第一行的每个数字（2和1），各自乘以第二个矩阵第一列对应位置的数字（1和1），然后将乘积相加（ 2 x 1 + 1 x 1），得到结果矩阵左上角的那个值3。也就是说，结果矩阵第m行与第n列交叉位置的那个值，等于第一个矩阵第m行与第二个矩阵第n列，对应位置的每个值的乘积之和。
#     - 线性代数基于矩阵的推导：
#         - https://www.cnblogs.com/alantu2018/p/8528299.html

# %%
np.dot(arr,arr.T)
# Out:
# array([[14767,  5834,  6620, 11907,  8986],
#        [ 5834, 15276,  9766, 14820, 12320],
#        [ 6620,  9766, 15580, 12542, 12858],
#        [11907, 14820, 12542, 22291, 18132],
#        [ 8986, 12320, 12858, 18132, 18656]])

# %% [markdown]
# - 思考：一个行向量乘以该向量的转置等于什么？
#     - 等于一个常数
